# %%
import pandas as pd

# %%
df = pd.read_csv(
    r"C:\Users\HP\Downloads\Amazon Sale Report\Amazon Sale Report.csv",
    low_memory=False
)

df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df.shape
# Out:
# (128975, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
df.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
df['Unnamed: 22'].value_counts(dropna=False)
# Out:
# Unnamed: 22
# False    79925
# NaN      49050
# Name: count, dtype: int64

# %%
df['index'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: index, dtype: int64

# %%
df['Date'].head()
# Out:
# 0    04-30-22
# 1    04-30-22
# 2    04-30-22
# 3    04-30-22
# 4    04-30-22
# Name: Date, dtype: object

# %%
df['Unnamed: 22'].unique()
# Out:
# array([nan, False], dtype=object)

# %%
df.drop(columns=['Unnamed: 22'], inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
df['Date'] = pd.to_datetime(
    df['Date'],
    format='%m-%d-%y',
    errors='coerce'
)

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.duplicated().sum()
# Out:
# np.int64(6)

# %%
df[df.duplicated()]
# Out:
#                   Order ID       Date     Status Fulfilment Sales Channel   \
# 30661  406-0372545-6086735 2022-04-12  Cancelled     Amazon      Amazon.in
# 41292  408-0373839-4433120 2022-04-05  Cancelled     Amazon      Amazon.in
# 79845  171-9628368-5329958 2022-05-07  Cancelled     Amazon      Amazon.in
# 85791  171-3249942-2207542 2022-05-03    Shipped     Amazon      Amazon.in
# 86419  405-8669298-3850736 2022-05-03    Shipped     Amazon      Amazon.in
# 98955  407-4853873-4978725 2022-06-22    Shipped     Amazon      Amazon.in
#
#       ship-service-level    Style              SKU Category Size  ...  \
# 30661          Expedited   SET197   SET197-KR-NP-L      Set    L  ...
# 41292          Expedited  JNE3501     JNE3501-KR-M    kurta    M  ...
# 79845          Expedited    J0329       J0329-KR-L    kurta    L  ...
# 85791          Expedited   SET323  SET323-KR-NP-XL      Set   XL  ...
# 86419          Expedited  MEN5025  MEN5025-KR-XXXL    kurta  3XL  ...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7792
# Amount                 7792
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49150
# B2B                       0
# fulfilled-by          89692
# Unnamed: 22           49048
# dtype: int64

# %%
(df.isnull().sum() / len(df) * 100).round(2)
# Out:
# index                  0.00
# Order ID               0.00
# Date                   0.00
# Status                 0.00
# Fulfilment             0.00
# Sales Channel          0.00
# ship-service-level     0.00
# Style                  0.00
# SKU                    0.00
# Category               0.00
# Size                   0.00
# ASIN                   0.00
# Courier Status         5.33
# Qty                    0.00
# currency               6.04
# Amount                 6.04
# ship-city              0.03
# ship-state             0.03
# ship-postal-code       0.03
# ship-country           0.03
# promotion-ids         38.11
# B2B                    0.00
# fulfilled-by          69.55
# dtype: float64

# %%
df[df['Amount'].isna()]['Status'].value_counts()
# Out:
# Status
# Cancelled                       7566
# Shipped                          208
# Shipped - Delivered to Buyer       8
# Shipping                           8
# Shipped - Returned to Seller       3
# Pending                            2
# Name: count, dtype: int64

# %%
df[df['Amount'].isna()]['currency'].value_counts(dropna=False)
# Out:
# currency
# NaN    7795
# Name: count, dtype: int64

# %%
df['Status'].value_counts()
# Out:
# Status
# Shipped                          77804
# Shipped - Delivered to Buyer     28769
# Cancelled                        18332
# Shipped - Returned to Seller      1953
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
df['Amount_Missing'] = df['Amount'].isna()

# %%
df[
    (df['Amount'].isna()) &
    (df['Status'].str.startswith('Shipped'))
][['Order ID', 'Status', 'Qty', 'Category', 'SKU', 'currency', 'Amount']].head(20)
# Out:
#                  Order ID   Status  Qty Category                 SKU currency  \
# 937   S02-5278980-4327051  Shipped   15   Blouse       BL017-63BLACK      NaN
# 1057  S02-9107114-0460608  Shipped    2      Set     SET315-KR-PP-XL      NaN
# 1615  405-7790745-1369118  Shipped    0    kurta        JNE3518-KR-M      NaN
# 1989  171-9673855-2321133  Shipped    0      Set      SET232-KR-PP-S      NaN
# 2424  404-7478762-7926753  Shipped    0      Set      SET331-KR-NP-S      NaN
# 2819  404-0814480-8157169  Shipped    0    kurta       JNE3291-KR-XL      NaN
# 3631  S02-1006261-5356758  Shipped    9    kurta    JNE2305-KR-533-L      NaN
# 3632  S02-3681731-6111841  Shipped    1    kurta    JNE2058-KR-339-L      NaN
# 3634  S02-1926028-4838217  Shipped    1    kurta     JNE3311-KR-A-XS      NaN
# 3636  S02-6828927-1180856  Shipped   13    kurta  JNE2305-KR-533-XXL      NaN
# 3637  S02-3409426-0744131  Shipped    2   Blouse         BL020-71RED      NaN
# ...

# %%
sales_df = df[df['Amount'].notna()].copy()

# %%
sales_df.shape
# Out:
# (121180, 24)

# %%
sales_df['Amount'].isna().sum()
# Out:
# np.int64(0)

# %%
df[df['Courier Status'].isna()]['Status'].value_counts()
# Out:
# Status
# Cancelled                       6861
# Shipped - Delivered to Buyer       8
# Shipped - Returned to Seller       3
# Name: count, dtype: int64

# %%
df['Courier Status'] = df['Courier Status'].fillna('Not Applicable')

# %%
df['Courier Status'].isna().sum()
# Out:
# np.int64(0)

# %%
df['promotion-ids'].value_counts(dropna=False).head(10)
# Out:
# promotion-ids
# ...

# %%
df['promotion-ids'].value_counts(dropna=False).head(10)
# Out:
# promotion-ids
# ...

# %%
df['promotion-ids'] = df['promotion-ids'].fillna('No Promotion')

# %%
df['promotion-ids'].isna().sum()
# Out:
# np.int64(0)

# %%
df['fulfilled-by'].value_counts(dropna=False)
# Out:
# fulfilled-by
# NaN          89698
# Easy Ship    39277
# Name: count, dtype: int64

# %%
df['fulfilled-by'] = df['fulfilled-by'].fillna('Not Applicable')

# %%
df['fulfilled-by'].isna().sum()
# Out:
# np.int64(0)

# %%
df[df['ship-city'].isna()][
    ['Order ID', 'ship-city', 'ship-state', 'ship-postal-code', 'ship-country']
]
# Out:
#                    Order ID ship-city ship-state  ship-postal-code  \
# 1871    404-0566904-4825137       NaN        NaN               NaN
# 1872    404-0566904-4825137       NaN        NaN               NaN
# 8752    406-4003386-8768363       NaN        NaN               NaN
# 11215   402-0107720-7057168       NaN        NaN               NaN
# 13252   407-4532637-8415521       NaN        NaN               NaN
# 15688   404-9229894-8608305       NaN        NaN               NaN
# 16787   402-4919636-4333150       NaN        NaN               NaN
# 18351   405-4927647-8064368       NaN        NaN               NaN
# 22930   402-8628677-0457954       NaN        NaN               NaN
# 24986   406-4079063-8291520       NaN        NaN               NaN
# 30379   404-7506843-7913132       NaN        NaN               NaN
# 37963   407-3064376-9158743       NaN        NaN               NaN
# 37964   407-3064376-9158743       NaN        NaN               NaN
# ...

# %%
df['ship-city'] = df['ship-city'].fillna('Unknown')
df['ship-state'] = df['ship-state'].fillna('Unknown')
df['ship-country'] = df['ship-country'].fillna('Unknown')

# %%
df['ship-postal-code'] = df['ship-postal-code'].fillna(-1)

# %%
df[['ship-city', 'ship-state', 'ship-postal-code', 'ship-country']].isnull().sum()
# Out:
# ship-city           0
# ship-state          0
# ship-postal-code    0
# ship-country        0
# dtype: int64

# %%
df['Qty'].value_counts().sort_index()
# Out:
# Qty
# 0      12807
# 1     115780
# 2        341
# 3         32
# 4          9
# 5          2
# 8          1
# 9          1
# 13         1
# 15         1
# Name: count, dtype: int64

# %%
df['Qty'].describe()
# Out:
# count    128975.000000
# mean          0.904431
# std           0.313354
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           1.000000
# max          15.000000
# Name: Qty, dtype: float64

# %%
df[df['Qty'] == 0]['Status'].value_counts()
# Out:
# Status
# Cancelled                       12701
# Shipped                            93
# Shipped - Delivered to Buyer        8
# Shipped - Returned to Seller        3
# Pending                             2
# Name: count, dtype: int64

# %%
df[
    (df['Qty'] == 0) &
    (df['Status'] != 'Cancelled')
][['Order ID', 'Status', 'Category', 'SKU', 'Amount', 'currency']].head(20)
# Out:
#                   Order ID                        Status Category  \
# 1615   405-7790745-1369118                       Shipped    kurta
# 1989   171-9673855-2321133                       Shipped      Set
# 2424   404-7478762-7926753                       Shipped      Set
# 2819   404-0814480-8157169                       Shipped    kurta
# 9255   405-1892033-5435562                       Shipped      Set
# 11145  404-7498280-7477149                       Shipped      Set
# 15881  406-5281014-6299540                       Shipped      Top
# 16191  408-3851867-4615501                       Shipped    kurta
# 16599  403-8676035-5065939                       Shipped      Set
# 18336  405-1252351-8764324                       Shipped      Set
# 18891  408-4196439-4813936                       Shipped    kurta
# 18894  408-2656493-8935504  Shipped - Delivered to Buyer      Set
# 19292  408-0017934-6791513  Shipped - Delivered to Buyer      Set
# ...

# %%
df[df['Amount'] < 0][['Order ID', 'Status', 'Qty', 'Category', 'Amount']].head(20)
# Out:
# Empty DataFrame
# Columns: [Order ID, Status, Qty, Category, Amount]
# Index: []

# %%
df['Amount'].describe()
# Out:
# count    121180.000000
# mean        648.561465
# std         281.211687
# min           0.000000
# 25%         449.000000
# 50%         605.000000
# 75%         788.000000
# max        5584.000000
# Name: Amount, dtype: float64

# %%
df[df['Amount'] == 0]['Status'].value_counts()
# Out:
# Status
# Shipped                          1518
# Shipped - Delivered to Buyer      716
# Shipped - Returned to Seller       51
# Shipped - Picked Up                28
# Pending                            17
# Pending - Waiting for Pick Up       9
# Shipped - Lost in Transit           2
# Shipped - Returning to Seller       2
# Name: count, dtype: int64

# %%
df['currency'].value_counts(dropna=False)
# Out:
# currency
# INR    121180
# NaN      7795
# Name: count, dtype: int64

# %%
df['currency'] = df['currency'].fillna('Not Available')

# %%
df['currency'].isna().sum()
# Out:
# np.int64(0)

# %%
sales_df = df[df['Amount'].notna()].copy()

# %%
df['Date'].min()
# Out:
# '03-31-22'

# %%
df['Date'].max()
# Out:
# '06-29-22'

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month_name()
df['Month_Number'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
df[['Date', 'Year', 'Month', 'Month_Number', 'Day']].head()
# Out:
#         Date  Year  Month  Month_Number  Day
# 0 2022-04-30  2022  April             4   30
# 1 2022-04-30  2022  April             4   30
# 2 2022-04-30  2022  April             4   30
# 3 2022-04-30  2022  April             4   30
# 4 2022-04-30  2022  April             4   30

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
sales_df = df[df['Amount'].notna()].copy()

# %%
sales_df.shape
# Out:
# (121180, 28)

# %%
sales_df['Amount'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Sales'] = df['Amount']

# %%
df['Sales'].sum()
# Out:
# np.float64(78592678.3)

# %%
sales_df['Amount'].sum()
# Out:
# np.float64(78592678.30000001)

# %%
df['Order ID'].nunique()
# Out:
# 120378

# %%
df['Order ID'].count()
# Out:
# np.int64(128975)

# %%
df['Order ID'].count()
# Out:
# np.int64(128975)

# %%
df['Qty'].sum()
# Out:
# np.int64(116649)

# %%
df['Sales'] = df['Amount']

# %%
df.groupby('Order ID')['Sales'].sum().mean()
# Out:
# np.float64(652.8824062536344)

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Set              39204124.03
# kurta            21299546.70
# Western Dress    11216072.69
# Top               5347792.30
# Ethnic Dress       791217.66
# Blouse             458408.18
# Bottom             150667.98
# Saree              123933.76
# Dupatta               915.00
# Name: Sales, dtype: float64

# %%
df.groupby(['Year', 'Month_Number', 'Month'])['Sales'].sum().sort_values()
# Out:
# Year  Month_Number  Month
# 2022  3             March      101683.85
#       6             June     23425809.38
#       5             May      26226476.75
#       4             April    28838708.32
# Name: Sales, dtype: float64

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m-%d-%y')

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month_name()
df['Month_Number'] = df['Date'].dt.month

# %%
df['Sales'] = df['Amount']

# %%
df.groupby(['Year', 'Month_Number', 'Month'])['Sales'].sum().sort_values()
# Out:
# Year  Month_Number  Month
# 2022  3             March      101683.85
#       6             June     23425809.38
#       5             May      26226476.75
#       4             April    28838708.32
# Name: Sales, dtype: float64

# %%
df.groupby('Status')['Sales'].sum().sort_values(ascending=False)
# Out:
# Status
# Shipped                          50324255.0
# Shipped - Delivered to Buyer     18650815.0
# Cancelled                         6919284.3
# Shipped - Returned to Seller      1269644.0
# Shipped - Picked Up                661252.0
# Pending                            430271.0
# Pending - Waiting for Pick Up      192138.0
# Shipped - Returning to Seller      107620.0
# Shipped - Out for Delivery          26971.0
# Shipped - Rejected by Buyer          7295.0
# Shipped - Lost in Transit            1997.0
# Shipped - Damaged                    1136.0
# Shipping                                0.0
# Name: Sales, dtype: float64

# %%
df.groupby('SKU')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# SKU
# J0230-SKD-M        527699.20
# JNE3797-KR-L       524581.77
# J0230-SKD-S        479937.14
# JNE3797-KR-M       454290.16
# JNE3797-KR-S       407302.57
# JNE3797-KR-XL      332155.24
# J0230-SKD-L        305616.95
# JNE3797-KR-XS      303616.70
# SET268-KR-NP-XL    284058.96
# JNE3797-KR-XXXL    276375.80
# Name: Sales, dtype: float64

# %%
df.groupby('ship-state')['Sales'].sum().sort_values(ascending=False).head(10)
# Out:
# ship-state
# MAHARASHTRA       13335534.14
# KARNATAKA         10481114.37
# TELANGANA          6916615.65
# UTTAR PRADESH      6816642.08
# TAMIL NADU         6515650.11
# DELHI              4235215.97
# KERALA             3830227.58
# WEST BENGAL        3507880.44
# ANDHRA PRADESH     3219831.72
# HARYANA            2882092.99
# Name: Sales, dtype: float64

# %%
df.groupby('Fulfilment')['Sales'].sum().sort_values(ascending=False)
# Out:
# Fulfilment
# Amazon      54322151.0
# Merchant    24270527.3
# Name: Sales, dtype: float64

# %%
df.groupby('B2B')['Sales'].sum().sort_values(ascending=False)
# Out:
# B2B
# False    78001457.51
# True       591220.79
# Name: Sales, dtype: float64

# %%
df.to_csv("Amazon_Sales_Cleaned.csv", index=False)

# %%
import os
os.path.exists("Amazon_Sales_Cleaned.csv")
# Out:
# True

# %%
df.to_csv(r"C:\Users\HP\Downloads\Amazon_Sales_Cleaned.csv", index=False)
